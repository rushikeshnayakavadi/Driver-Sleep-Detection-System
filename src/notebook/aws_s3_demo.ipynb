# %%
import boto3
import os

AWS_ACCESS_KEY = "AKIAYKFQQZHUAY6YOHPY"
AWS_SECRET_KEY = "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"
BUCKET_NAME = "driver-sleep-detection-data"

s3_client = boto3.client(
    "s3",
    aws_access_key_id=AWS_ACCESS_KEY,
    aws_secret_access_key=AWS_SECRET_KEY,
)

# Define dataset directory
dataset_dir = "notebook/dataset_new"

# Function to upload folder recursively
def upload_folder_to_s3(folder_path, bucket_name, s3_folder):
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            local_file_path = os.path.join(root, file)
            s3_key = os.path.relpath(local_file_path, dataset_dir)  # Maintain structure
            s3_client.upload_file(local_file_path, bucket_name, f"{s3_folder}/{s3_key}")
            print(f"Uploaded {local_file_path} to s3://{bucket_name}/{s3_folder}/{s3_key}")

# Upload both train/ and test/ folders
upload_folder_to_s3(os.path.join(dataset_dir, "train"), BUCKET_NAME, "dataset_new/train")
upload_folder_to_s3(os.path.join(dataset_dir, "test"), BUCKET_NAME, "dataset_new/test")

print("Train and Test folders uploaded successfully to S3!")
# Out:
# Train and Test folders uploaded successfully to S3!

# %%
import boto3
import os

# Initialize S3 client
s3 = boto3.client("s3")
bucket_name = "driver-sleep-detection-data"

def upload_folder_to_s3(local_folder, s3_folder):
    if not os.path.exists(local_folder):
        print(f"Local folder '{local_folder}' does not exist!")
        return
    
    for root, _, files in os.walk(local_folder):
        for file in files:
            local_path = os.path.join(root, file)
            
            # Preserve subfolder names (Closed, no_yawn, Open, yawn)
            relative_path = os.path.relpath(local_path, local_folder)  
            s3_path = os.path.join(s3_folder, relative_path).replace("\\", "/")  # Convert to S3 format
            
            print(f"📤 Uploading {local_path} → s3://{bucket_name}/{s3_path}")
            s3.upload_file(local_path, bucket_name, s3_path)
    
    print(f"Upload completed for '{local_folder}'")

# Upload Train and Test folders with exact subfolder names
upload_folder_to_s3("dataset_new/train", "train")
upload_folder_to_s3("dataset_new/test", "test")
# Out:
# 📤 Uploading dataset_new/train\Closed\_0.jpg → s3://driver-sleep-detection-data/train/Closed/_0.jpg
# 📤 Uploading dataset_new/train\Closed\_1.jpg → s3://driver-sleep-detection-data/train/Closed/_1.jpg
# 📤 Uploading dataset_new/train\Closed\_10.jpg → s3://driver-sleep-detection-data/train/Closed/_10.jpg
# 📤 Uploading dataset_new/train\Closed\_100.jpg → s3://driver-sleep-detection-data/train/Closed/_100.jpg
# 📤 Uploading dataset_new/train\Closed\_101.jpg → s3://driver-sleep-detection-data/train/Closed/_101.jpg
# 📤 Uploading dataset_new/train\Closed\_102.jpg → s3://driver-sleep-detection-data/train/Closed/_102.jpg
# 📤 Uploading dataset_new/train\Closed\_103.jpg → s3://driver-sleep-detection-data/train/Closed/_103.jpg
# 📤 Uploading dataset_new/train\Closed\_104.jpg → s3://driver-sleep-detection-data/train/Closed/_104.jpg
# 📤 Uploading dataset_new/train\Closed\_105.jpg → s3://driver-sleep-detection-data/train/Closed/_105.jpg
# ...
